# %%
#import dependencies

# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load in file
file_path = "Resources/Reason_for_assistance.csv"

# %%
# Read and display the CSV with Pandas
summary_df = pd.read_csv(file_path,encoding='ISO-8859-1')
summary_df
# Out:
#                                      Table of contents Unnamed: 1  \
# 0    Table CLIENTS.20: Clients, by reasons for seek...        NaN
# 1                                                  NaN        NaN
# 2                                    State/\nterritory      Group
# 3                                             National  Financial
# 4                                             National  Financial
# ..                                                 ...        ...
# 294  2.  The reason group is a count of unique clie...        NaN
# 295  3.  Percentages have been calculated using tot...        NaN
# 296                            nil or rounded to zero        NaN
# 297                            . .      not applicable        NaN
# 298                                                NaN        NaN
#
#                         Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                              NaN        NaN        NaN
# 1                              NaN        NaN        NaN
# 2    Reason for seeking assistance      Males    Females
# 3                        Financial     62,835     81,714
# 4           Financial difficulties     51,060     67,384
# ..                             ...        ...        ...
# 294                            NaN        NaN        NaN
# 295                            NaN        NaN        NaN
# 296                            NaN        NaN        NaN
# 297                            NaN        NaN        NaN
# 298                            NaN        NaN        NaN
#
#                  Unnamed: 5                Unnamed: 6
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2    Total clients (number)  Total clients (per cent)
# 3                   144,549                      50.3
# 4                   118,444                      41.2
# ..                      ...                       ...
# 294                     NaN                       NaN
# 295                     NaN                       NaN
# 296                     NaN                       NaN
# 297                     NaN                       NaN
# 298                     NaN                       NaN
#
# [299 rows x 7 columns]

# %%
#Clean dataframe
#Changing the name of columns/headers

summary_df = summary_df.rename(columns={
    'Table of contents': 'State/territory', 
    'Unnamed: 1': 'Group',
    'Unnamed: 2':'Reason for seeking assistance',
    'Unnamed: 3':'Males',
    'Unnamed: 4':'Females',
    'Unnamed: 5':'Total clients (number)',
    'Unnamed: 6':'Total clients (per cent)'
})

#Deleting first two rows (irrelavant)
summary_df = summary_df.iloc[2:]
#drop NA
summary_df = summary_df.dropna(how = "any")
#filtering only WA data
clean_df = summary_df[summary_df['State/territory'] == "WA"] 
#removing commas from Total clients (number)

clean_df["Total clients (number)"] = clean_df["Total clients (number)"].str.replace(",","")
clean_df["Males"] = clean_df["Males"].str.replace(",","")
clean_df["Females"] = clean_df["Females"].str.replace(",","")


clean_df = clean_df.astype({"Total clients (number)":"float"})
clean_df = clean_df.astype({"Males":"float"})
clean_df = clean_df.astype({"Females":"float"})


clean_df
# Out:
# C:\Users\Laurent\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Laurent\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Laurent\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     State/territory                        Group  \
# 131              WA                    Financial
# 132              WA                    Financial
# 133              WA                    Financial
# 134              WA                    Financial
# 135              WA                    Financial
# 136              WA                    Financial
# 137              WA                Accommodation
# 138              WA                Accommodation
# 139              WA                Accommodation
# 140              WA                Accommodation
# 141              WA  Interpersonal relationships
# 142              WA  Interpersonal relationships
# 143              WA  Interpersonal relationships
# 144              WA  Interpersonal relationships
# 145              WA  Interpersonal relationships
# 146              WA  Interpersonal relationships
# 147              WA                       Health
# 148              WA                       Health
# 149              WA                       Health
# 150              WA                       Health
# 151              WA                       Health
# 152              WA                        Other
# 153              WA                        Other
# 154              WA                        Other
# 155              WA                        Other
# 156              WA                        Other
# 157              WA                        Other
# 158              WA                        Other
# 159              WA                        Other
# 160              WA                        Other
# 161              WA                        Other
# 162              WA                   Not stated
#
#                          Reason for seeking assistance   Males  Females  \
# 131                                          Financial  4445.0   6109.0
# 132                             Financial difficulties  3585.0   5026.0
# 133                       Housing affordability stress  2081.0   2749.0
# 134                            Employment difficulties   470.0    408.0
# 135                                       Unemployment  1543.0   1603.0
# 136                               Problematic gambling    13.0     12.0
# 137                                      Accommodation  3905.0   5174.0
# 138                                     Housing crisis  2135.0   2954.0
# 139    Inadequate or inappropriate dwelling conditions  2002.0   2550.0
# 140                       Previous accommodation ended  1502.0   1746.0
# 141                        Interpersonal relationships  3889.0   9496.0
# 142               Time out from family/other situation  1391.0   2645.0
# 143                      Relationship/family breakdown  1818.0   3991.0
# 144                                       Sexual abuse    58.0    582.0
# 145                       Family and domestic violence  2208.0   7587.0
# 146                                Non-family violence   261.0    515.0
# 147                                             Health  2708.0   3933.0
# 148                               Mental health issues  1308.0   2010.0
# 149                                     Medical issues  1229.0   1626.0
# 150                  Problematic drug or substance use   890.0   1088.0
# 151                            Problematic alcohol use   455.0    646.0
# 152                                              Other  4631.0   6212.0
# 153             Transition from custodial arrangements   269.0    127.0
# 154  Transition from foster care and child safety r...    50.0     62.0
# 155            Transition from other care arrangements    98.0    118.0
# 156     Discrimination including racial discrimination    31.0     40.0
# 157                                          Itinerant   766.0    635.0
# 158  Unable to return home due to environmental rea...   190.0    364.0
# 159  Disengagement with school or other education a...   141.0    176.0
# 160            Lack of family and/or community support  2259.0   3477.0
# 161                                              Other  1973.0   2583.0
# 162                                         Not stated    10.0     22.0
#
#      Total clients (number) Total clients (per cent)
# 131                 10554.0                     42.3
# 132                  8611.0                     34.5
# 133                  4830.0                     19.4
# 134                   878.0                      3.5
# 135                  3146.0                     12.6
# 136                    25.0                      0.1
# 137                  9079.0                     36.4
# 138                  5089.0                     20.4
# 139                  4552.0                     18.3
# 140                  3248.0                     13.0
# 141                 13385.0                     53.7
# 142                  4036.0                     16.2
# 143                  5809.0                     23.3
# 144                   640.0                      2.6
# 145                  9795.0                     39.3
# 146                   776.0                      3.1
# 147                  6641.0                     26.6
# 148                  3318.0                     13.3
# 149                  2855.0                     11.5
# 150                  1978.0                      7.9
# 151                  1101.0                      4.4
# 152                 10843.0                     43.5
# 153                   396.0                      1.6
# 154                   112.0                      0.4
# 155                   216.0                      0.9
# 156                    71.0                      0.3
# 157                  1401.0                      5.6
# 158                   554.0                      2.2
# 159                   317.0                      1.3
# 160                  5736.0                     23.0
# 161                  4556.0                     18.3
# 162                    32.0                      . .

# %%
#Using Groupby

grouped_summary_df = clean_df.groupby(['Group']).sum()
grouped_summary_df
# Out:
#                                Males  Females  Total clients (number)
# Group
# Accommodation                 9544.0  12424.0                 21968.0
# Financial                    12137.0  15907.0                 28044.0
# Health                        6590.0   9303.0                 15893.0
# Interpersonal relationships   9625.0  24816.0                 34441.0
# Not stated                      10.0     22.0                    32.0
# Other                        10408.0  13794.0                 24202.0

# %%
# Initial assumption - based on personal encounter/observation

# (assumption 1) Males are more subjected to homeless
# (assumption 2) Drug and Alcohol would be the main reason for homeless as most homeless are under the influence

# %% [markdown]
# # Gender Analysis to answer (assumption 1)

# %%
# Gender Analysis to answer (assumption 1)

Male_stat = clean_df["Males"].sum()
Female_stat = clean_df["Females"].sum()
Ratio_stat = (Female_stat/Male_stat)
Ratio_stat = round(Ratio_stat,2)
print(f"The total number of male homeless in WA is: {Male_stat}")
print(f"The total number of female homeless in WA is: {Female_stat}")
print(f"Females are {Ratio_stat} times are more likely to be homeless than males")
# Out:
# The total number of male homeless in WA is: 48314.0
# The total number of female homeless in WA is: 76266.0
# Females are 1.58 times are more likely to be homeless than males

# %% [markdown]
# # Visualizing top contributors of homelessness by group

# %%
# Creating a pie chart two seperate groups

# Labels for the sections of our pie chart
labels = ["Accommodation", "Financial", "Health", "Interpersonal relationships", "Other"]
sizes = [21968.0, 28044.0, 15893.084, 34441.0, 24202.0]

# The colors of each section of the pie chart
colors = ["lightskyblue", "orange", "lightcoral", "red", "yellow"]

# Tells matplotlib to seperate the "Humans" section from the others
explode = (0, 0, 0, 0.1,0)

# %%
# Creates the pie chart based upon the values above
# Automatically finds the percentages of each part of the pie chart
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
# Give our chart some labels and a tile
plt.title("Main contributing factors to homelessness")
plt.show()

# %% [markdown]
# # Validating (assumption 2) Drug and Alcohol would be the main contributing factors to homelessness as most homeless are under the influence

# %%
#DataFrame 1 (top 5 contributing factors - males) - Bar chart

# %%
#DataFrame 2 (top 5 contributing factors - females) - Bar chart

# %%
#Alternative have a dataframe with a graph grouped by sub-reason

# %%
# Organising data frame starting from most to least number of clients


clean_df[["Reason for seeking assistance", "Total clients (number)"]].groupby("Reason for seeking assistance").max()
clean_df = clean_df.sort_values("Total clients (number)",ascending=False)
clean_df.head() #top 5 reasons that contribute to homelessness
# Out:
#     State/territory                        Group  \
# 141              WA  Interpersonal relationships
# 152              WA                        Other
# 131              WA                    Financial
# 145              WA  Interpersonal relationships
# 137              WA                Accommodation
#
#     Reason for seeking assistance   Males  Females  Total clients (number)  \
# 141   Interpersonal relationships  3889.0   9496.0                 13385.0
# 152                         Other  4631.0   6212.0                 10843.0
# 131                     Financial  4445.0   6109.0                 10554.0
# 145  Family and domestic violence  2208.0   7587.0                  9795.0
# 137                 Accommodation  3905.0   5174.0                  9079.0
#
#     Total clients (per cent)
# 141                     53.7
# 152                     43.5
# 131                     42.3
# 145                     39.3
# 137                     36.4

# %%
# Create an array that contains the number of clients per interpersonal relationships reasons

client_num = [13385.0,1978.0,1101.0]
Reason_for_seeking_assistance = [
    "Interpersonal relationships",
    "Problematic drug or substance use",
    "Problematic alcohol use"
]

plt.bar(Reason_for_seeking_assistance, client_num, color='Red', align="center")
plt.xticks(Reason_for_seeking_assistance, Reason_for_seeking_assistance, rotation="vertical")
           
# Give our chart some labels and a tile
plt.title("Main contributing factor homelessness vs Drug and Alcohol")
# plt.xlabel("Interpersonal relationship reasons")
plt.ylabel("Number of homeless clients")
plt.show()

# %%
# Create an array that contains the number of clients per interpersonal relationships reasons

client_num = [13385.0,1978.0,1101.0]
Reason_for_seeking_assistance = [
    "Interpersonal relationships",
    "Problematic drug or substance use",
    "Problematic alcohol use"
]

plt.bar(Reason_for_seeking_assistance, client_num, color='Red', align="center")
plt.xticks(Reason_for_seeking_assistance, Reason_for_seeking_assistance, rotation="vertical")
           
# Give our chart some labels and a tile
plt.title("Main contributing factor homelessness vs Drug and Alcohol")
# plt.xlabel("Interpersonal relationship reasons")
plt.ylabel("Number of homeless clients")
plt.show()

# %%
# Sub-dividing Interpersonal relationships into specific reasons

Interpersonal_rel_df = clean_df.loc[clean_df["Group"]=="Interpersonal relationships"]
Interpersonal_rel_df
# Out:
#     State/territory                        Group  \
# 141              WA  Interpersonal relationships
# 142              WA  Interpersonal relationships
# 143              WA  Interpersonal relationships
# 144              WA  Interpersonal relationships
# 145              WA  Interpersonal relationships
# 146              WA  Interpersonal relationships
#
#             Reason for seeking assistance   Males  Females  \
# 141           Interpersonal relationships  3889.0   9496.0
# 142  Time out from family/other situation  1391.0   2645.0
# 143         Relationship/family breakdown  1818.0   3991.0
# 144                          Sexual abuse    58.0    582.0
# 145          Family and domestic violence  2208.0   7587.0
# 146                   Non-family violence   261.0    515.0
#
#      Total clients (number) Total clients (per cent)
# 141                 13385.0                     53.7
# 142                  4036.0                     16.2
# 143                  5809.0                     23.3
# 144                   640.0                      2.6
# 145                  9795.0                     39.3
# 146                   776.0                      3.1

# %%
# Create an array that contains the number of clients per interpersonal relationships reasons

clients_num = [13385.0,4036.0,5809.0,640.0,9795.0,776.0]
Interpersonal_relation_reasons = [
    "Interpersonal relationships",
    "Time out from family/other situation",
    "Relationship/family breakdown",
    "Sexual abuse",
    "Family and domestic violence",
    "Non-family violence"
]

# %%
# Tell matplotlib that we will be making a bar chart
# Clients is our y axis and x_axis is, of course, our x axis
# We apply align="edge" to ensure our bars line up with our tick marks
plt.bar(Interpersonal_relation_reasons, clients_num, color='blue', alpha=0.5, align="center")
plt.xticks(Interpersonal_relation_reasons, Interpersonal_relation_reasons, rotation="vertical")


# # Sets the x limits of the current chart
# plt.xlim(-0.75, len(Interpersonal_relation_reasons)-0.25)

# # Sets the y limits of the current chart
# plt.ylim(0, max(clients_num)+14000)

# Give our chart some labels and a tile
plt.title("Interpersonal Relationsip reasons contributing to Homelessness")
# plt.xlabel("Interpersonal relationship reasons")
plt.ylabel("Number of homeless clients")
plt.show()

# %% [markdown]
# # Family and Domestic Violence analysis in Western Australia

# %%
# Load in file
Dom_Perth_path = "Resources/Clients who have experienced family and domestic violence, by state and territory, 2019–20.csv"

# %%
# Read and display the CSV with Pandas
d_violence_perth__df = pd.read_csv(Dom_Perth_path,encoding='ISO-8859-1')
d_violence_perth__df.head()
# Out:
#                                    Table of contents Unnamed: 1 Unnamed: 2  \
# 0  Table FDV.2: Clients who have experienced fami...        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                                          Data type        Sex        NSW
# 3                                   Clients (number)      Males      7,332
# 4                                   Clients (number)    Females     20,123
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        Vic        Qld         WA         SA        Tas        ACT
# 3     11,878      3,691      2,415      1,155        407        473
# 4     41,324     11,858      8,012      5,314      1,368      1,143
#
#   Unnamed: 9  Unnamed: 10
# 0        NaN          NaN
# 1        NaN          NaN
# 2         NT  National(a)
# 3        988       27,928
# 4      3,524       91,254

# %%
#Clean dataframe
#Changing the name of columns/headers

d_violence_perth__df = d_violence_perth__df.rename(columns={
    'Table of contents': 'Data type', 
    'Unnamed: 1': 'Sex',
    'Unnamed: 2':'NSW',
    'Unnamed: 3':'Vic',
    'Unnamed: 4':'Qld',
    'Unnamed: 5':'WA',
    'Unnamed: 6':'SA',
    'Unnamed: 7':'Tas',
    'Unnamed: 8':'ACT',
    'Unnamed: 9':'NT',
    'Unnamed: 10':'National(a)'
    

})

#Deleting first 3 rows (irrelavant)
d_violence_perth__df = d_violence_perth__df.iloc[3:]
d_violence_perth__df
d_violence_perth__df = d_violence_perth__df.drop(d_violence_perth__df.index[5:23])
d_violence_perth__df
#drop NA
d_violence_perth__df = d_violence_perth__df.dropna(how = "any")
d_violence_perth__df

# removing commas from WA 

d_violence_perth__df["WA"] = d_violence_perth__df["WA"].str.replace(",","")



d_violence_perth__df = d_violence_perth__df.astype({"WA":"float"})

# 
d_violence_perth__df
# Out:
#                   Data type          Sex     NSW      Vic     Qld       WA  \
# 3          Clients (number)        Males   7,332   11,878   3,691   2415.0
# 4          Clients (number)      Females  20,123   41,324  11,858   8012.0
# 5          Clients (number)  All clients  27,455   53,202  15,549  10427.0
# 6  Support periods (number)        Males  10,771   26,128   5,247   3574.0
# 7  Support periods (number)      Females  31,887  101,132  18,445  13553.0
#
#        SA    Tas    ACT     NT National(a)
# 3   1,155    407    473    988      27,928
# 4   5,314  1,368  1,143  3,524      91,254
# 5   6,469  1,775  1,616  4,512     119,182
# 6   2,081    865    678  1,436      50,780
# 7  10,485  3,096  1,933  6,078     186,609

# %%
#Narrow done a data frame

# %% [markdown]
# # Family and Domestic violence analysis in Australia

# %%
# Load in file
file_path = "Resources/domestic_violence.csv"

# %%
# Read and display the CSV with Pandas
d_violence_df = pd.read_csv(file_path,encoding='ISO-8859-1')
d_violence_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17020/760351164.py in <module>
#       1 # Read and display the CSV with Pandas
# ----> 2 d_violence_df = pd.read_csv(file_path,encoding='ISO-8859-1')
#       3 d_violence_df
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     704                 encoding=ioargs.encoding,
#     705                 errors=errors,
# --> 706                 newline="",
#     707             )
#     708         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Resources/domestic_violence.csv'

# %%
#Clean dataframe
#Changing the name of columns/headers

d_violence_df = d_violence_df.rename(columns={
    'Table of contents': 'Data type', 
    'Unnamed: 1': 'Age group',
    'Unnamed: 2':'Males',
    'Unnamed: 3':'Males Percent',
    'Unnamed: 4':'Females',
    'Unnamed: 5':'Females Percent',
    'Unnamed: 6':'All clients',
    'Unnamed: 7':'All clients (percent)'

})

#Deleting first 4 rows (irrelavant)
d_violence_df = d_violence_df.iloc[4:]
# d_violence_df = d_violence_df.drop(d_violence_df.index[14:29])

#drop NA
d_violence_df = d_violence_df.dropna(how = "any")

# #removing commas from males and females

d_violence_df["Males"] = d_violence_df["Males"].str.replace(",","")
d_violence_df["Females"] = d_violence_df["Females"].str.replace(",","")


d_violence_df = d_violence_df.astype({"Males":"float"})
d_violence_df = d_violence_df.astype({"Females":"float"})


# 
d_violence_df

# %%
d_violence_df.drop(d_violence_df.loc[13:23].index, inplace=True)
d_violence_df

# %%
d_violence_df = d_violence_df[["Age group","Males","Females"]]
d_violence_df

# %%
Age_group = d_violence_df["Age group"]
male_v = d_violence_df["Males"]
female_v = d_violence_df["Females"]


Male, = plt.plot(Age_group, male_v, color="green", label="Male affected" )
Female, = plt.plot(Age_group, female_v, color="red", label="female affected" )

# Create a legend for our chart
plt.legend(handles=[Male, Female], loc="best")

# Resetting axis limits on my plot
# ax.set_ylim([100, 14000])# Show the chart
# plt.ylim(100.0, 25000.0)
plt.title("Client affected by Domestic Violence in Australia")
plt.xlabel("Age Group")
plt.ylabel("Client number")

plt.show()
